# %% [markdown]
# ## Ahmad 2610-4004
# ## Task : Assinment 2 (lab 2)
# ## class : Programming For AI Lab

# %% [markdown]
# ___

# %% [markdown]
# ## Task 1

# %% [markdown]
# 1. We are creating a database where we are going to store following items
# ## Customer Orders
# * order_id
# * customer_name
# * order_items
# * discount
# * order_total
# * order_date
# ## Temperature Monitoring
# * sensor_id
# * location
# * temperature_readings (list)
# * average_temperature
# * timestamp
# Your job is to identify the data-type to be used for each of above values. Also
# create an example for one record using variables and values of appropriate data
# types. Print Values

# %%
# declaring all variables
order_id = 101
customer_name = "Ahmad"
order_items = ["pen","book","laptop"]
discount = 10
order_total = 3
order_date = "20/02/2026"

# printing the types and values fo those varibales
print("Value of Order_id : ",order_id)
print(f"type of order_id : {type(order_id)}")

print(f"value of cutomer_name : {customer_name}")
print(f"type of customer_name : {type(customer_name)}")



print(f"value of : {order_items}")
print(f"type of order_tems: {type(order_items)}")


print(f"value of dicount : {discount}")
print(f"type of dicount : {type(discount)}")


print(f"value of order_total : {order_total}")
print(f"type of order_total :{type(order_total)}")


print(f"vlaue of order_date:  {order_date}")
print(f"type of order_date :  {type(order_date)}")


print(f"----------------2nd part of task 1-----------------------")
# temperature senser
# declaring the variables
sensor_id = 1001
location = "Islamabad"
temperature_readings = [30.0,33.2,34.1,31.0,28.0]
average_temperature = sum(temperature_readings ) / len(temperature_readings)
timestamp = "2026-02-20 09:16:53.160875"

# printing the required results




print(f"value of sensor_id {sensor_id}")
print(f"type of sensor_id : {type(sensor_id)}")

print(f"value of : {location}")
print(f"type of location :{type(location)}")


print(f"value of temperature_readings : {temperature_readings}")
print(f"type of temperature_readings : {type(temperature_readings)}")

print(f"value of timestamp  :{timestamp}")
# Out:
# Value of Order_id :  101
# type of order_id : <class 'int'>
# value of cutomer_name : Ahmad
# type of customer_name : <class 'str'>
# value of : ['pen', 'book', 'laptop']
# type of order_tems: <class 'list'>
# value of dicount : 10
# type of dicount : <class 'int'>
# value of order_total : 3
# type of order_total :<class 'int'>
# vlaue of order_date:  20/02/2026
# type of order_date :  <class 'str'>
# ----------------2nd part of task 1-----------------------
# value of sensor_id 1001
# type of sensor_id : <class 'int'>
# value of : Islamabad
# type of location :<class 'str'>
# value of temperature_readings : [30.0, 33.2, 34.1, 31.0, 28.0]
# type of temperature_readings : <class 'list'>
# value of timestamp  :2026-02-20 09:16:53.160875

# %% [markdown]
# ____
# ### Task 2

# %% [markdown]
# **Announcement Preview**
#
# You're developing an announcement preview tool for a messaging platform. The
# tool needs to provide a concise preview of longer messages.
#
# Task:
#
# Given a message: "Join us for the webinar on Aug 30, 2023, 2:00 PM (GMT)",
# perform the following tasks:
# * Calculate the length of the message.
# * Replace the word "webinar" with "online session".
# * Extract the date "Aug 30, 2023".
# * Create a shortened preview containing only the first 40 characters.
# * Extract time.
# Print all the results.

# %%
message = "Join us for the webinar on Aug 30, 2023, 2:00 PM (GMT)"
print(message)

print("length of message " , len(message))

message.replace("webinar","online session")
print("The new version ",message)

exact_date = message[27:39]
print(exact_date)

print(message[:40])

print("Time : ", message[40:48])
# Out:
# Join us for the webinar on Aug 30, 2023, 2:00 PM (GMT)
# length of message  54
# The new version  Join us for the webinar on Aug 30, 2023, 2:00 PM (GMT)
# Aug 30, 2023
# Join us for the webinar on Aug 30, 2023,
# Time :   2:00 PM

# %% [markdown]
# ___

# %% [markdown]
# ### TASK 3
# **Fitness Progress Tracker**
#
# You're developing a fitness progress tracker that records different exercises
# performed each day.
#
# Task:
# Given exercise logs: ['Running', 'Push-ups', 'Yoga', 'Swimming'], perform the
# following tasks:
# * Create an empty log for cardio exercises.
# * Append 'Cycling' to the cardio log.
# * Insert 'Plank' as the second exercise in the log.
# * Extract the exercise 'Yoga' from the list.
# * Create a brief cardio log containing only the first two exercises.
# * Extract all items from list
# * Extract all items except first and last from list
# Print all the results

# %%
excercise_log = ["Running","Push-ups","Yoga","Swimming"] # given list
cardio = [] # created empty cardio list
cardio.append("Cycling")
cardio.insert(1,"Plank")

# printing the results
print(f"Extracted : {excercise_log[2]}")
print(f"Extracted the first 2 items : {cardio[:2]}")
print(f"Extracting all the items  :{excercise_log[0:]}")
print(f"Extracted all except first and last : {excercise_log[1:3]}")
print(f"Full cardio list : {cardio}")
print(f"full excercise_log : {excercise_log}")
# Out:
# Extracted : Yoga
# Extracted the first 2 items : ['Cycling', 'Plank']
# Extracting all the items  :['Running', 'Push-ups', 'Yoga', 'Swimming']
# Extracted all except first and last : ['Push-ups', 'Yoga']
# Full cardio list : ['Cycling', 'Plank']
# full excercise_log : ['Running', 'Push-ups', 'Yoga', 'Swimming']

# %% [markdown]
# ___
# ### TASK 4
#
# **Bookshelf Organizer**
#
# You're working on a bookshelf organizer for a library app.
#
# Task:
# Given a list of book titles: ['Book A', 'Book B', 'Book C', 'Book D'], perform the
# following tasks:
# * Create an empty list for recommended books.
# * Append 'Recommended Book' to the recommended books list.
# * Insert 'Bestseller' as the second book in the list.
# * Extract the last book from the list.
# * Create a concise book list containing only the first three books.
# * Insert "Thore" as last item in list
# Print all the results.

# %%
# delaring the variables and lists
book_titles =['Book A', 'Book B', 'Book C', 'Book D']
recommended_books = []
recommended_books.append("Recommended Book")
recommended_books.insert(1,"Bestseller")
concise_books_list = book_titles[0:3]


# printing the lists
print(f"last Item :{book_titles[-1]}")
print(f"concise list of Books : {concise_books_list}")

# insertig Thore 
recommended_books.insert(3,"Thore")


print(f"Printing the initial book_titles list {book_titles}")
print(f"list of recommended_books :  {recommended_books}")
# Out:
# last Item :Book D
# concise list of Books : ['Book A', 'Book B', 'Book C']
# Printing the initial book_titles list ['Book A', 'Book B', 'Book C', 'Book D']
# list of recommended_books :  ['Recommended Book', 'Bestseller', 'Thore']

# %% [markdown]
# ___
# #### TASK 5
#
# **Coulomb's Law Calculator**
#
# You're developing a calculator to apply Coulomb's law for electrostatic
# interactions.
#
# Scenario:
#
# As a user, you'll input the charges (q1 and q2) of two objects and the distance
# (r) between them. The calculator will determine the electrostatic force (F)
# between the objects.
# Task:
# * Enter the charges of the two objects (q1 and q2) and the distance (r).
# * Calculate the electrostatic force (F) using Coulomb's law: F = k * q1 * q2 /
# r^2, where k is the electrostatic constant

# %%
q1 = float(input("Enter Charge q1(nC): "))
q2 = float(input("Enter Charge q2(nC) : "))
r = float(input("Enter the Distance between q1 and q2 (mm) : "))
k = k=8.9875517873681764e9


force = k * q1 * q2 / (r ** 2)

print("Force : ",force,"N")
# Out:
# Force :  4993084326.315654 N

# %% [markdown]
#  k = 8.99 × 10

# %%
rr = int(input("enter r : "))
print(rr**2)
# Out:
# 16
