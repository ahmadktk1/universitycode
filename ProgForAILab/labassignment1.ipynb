# %% [markdown]
# ## Ahmad 2610-4004
# ## Task : Assignment 1 (lab 1)
# ## class : Programming for AI Lab

# %% [markdown]
# ___

# %% [markdown]
# ### TASK 1
#
# Create variables for your name, age, department, and CGPA and print them using f-string.

# %%
# declaring the variables
name = "Ahmad"
age = 22
department = "Artificial Intelligence"
CGPA = 3.49

# now printing them

print(f"Name : {name}")
print(f"Age : {age}")
print(f"Department : {department}")
print(f"CGPA : {CGPA}")
# Out:
# Name : Ahmad
# Age : 22
# Department : Artificial Intelligence
# CGPA : 3.49

# %% [markdown]
# ___
#
# #### TASK 2
#
# Declare two integers and print their sum

# %%
num1 = 45
num2 = 78

sum = num1 + num2 

print(sum)
# Out:
# 123

# %% [markdown]
# ___
# #### TASK 3
#
# store your university name and print each word separatly

# %%
university = "Sir Syed CASE Institute"

for i in university:
    print(i)
# Out:
# S
# i
# r
#
# S
# y
# e
# d
#
# C
# A
# S
# E
#
# I
# n
# s
# t
# i
# t
# u
# t
# e

# %% [markdown]
# ___
# #### TASK 4
#
# Assign the same value to three variables and print them

# %%
var1 = 5
var2 = 5
var3 = 5

print(f"Variable 1 value : {var1}")
print(f"Variable 1 value : {var2}")
print(f"Variable 1 value : {var3}")
# Out:
# Variable 1 value : 5
# Variable 1 value : 5
# Variable 1 value : 5

# %% [markdown]
# ___
# #### TASK 5
# Create a boolean variable and print its value and type.

# %%
present = True

print(f"Value : {present}")
print(f"type : {type(present)}")
# Out:
# Value : True
# type : <class 'bool'>
