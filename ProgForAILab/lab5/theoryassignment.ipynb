# %% [markdown]
# Question 1: [Marks 5]
# Define a function process_numbers(nums) that:
# - Take a list of 15 integer elements from user, list have duplicate values.
# - Removes duplicates, sorts the list, and returns a tuple of (max, min, sum, average) using built-in
# functions.
# - Call this function in the main program and print results.

# %%
li = []
for i in range(5):
    
    inp = int(input("Enter no : "))
    li.append(inp)

for i in li:
    for a in li:
        if li[i] == li[a]:
            print(f"duplicated fount {li[a]}")
            li.remove(li[a])
# Out:
# duplicated fount 4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 9
#       7 for i in li:
#       8     for a in li:
# ----> 9         if li[i] == li[a]:
#      10             print(f"duplicated fount {li[a]}")
#      11             li.remove(li[a])
#
# IndexError: list index out of range
