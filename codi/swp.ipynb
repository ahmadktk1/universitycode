# %%
# we want to swap 2 numbers we can use temp variable 
a = 15
b = 10

a , b = b, a

# %%
print(f"a :{a}, and b {b}")
# Out:
# a :10, and b 15

# %%
def bubble_sort (array : list):
    n = len(array)
    for i in range(0,n-1):
        for j in range(0,n-i-1):
            if (array[j] > array[j+1]):
                array[j],array[j+1] = array[j+1],array[j]

# %%
ar = [2,4,1,6,8,9]
print(len(ar))
# Out:
# 6

# %%
print(sorte)
# Out:
# None

# %%
def bubbleSort(arr : list):
    n = len(arr)

    for i in range(0, n-1):
        for j in range ( 0, n-i-1):
            if(arr[j]>arr[j+1]):
                arr[j],arr[j+1] = arr[j+1],arr[j]

# %%
arrayy = [2,4,1,6,8,9]

bubbleSort(arrayy)

# %%
arrayy
# Out:
# [1, 2, 4, 6, 8, 9]

# %%
for i in arrayy:
    print(i)
# Out:
# 1
# 2
# 4
# 6
# 8
# 9
