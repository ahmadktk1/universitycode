# %%
message = input("Enter Message : ")
shift = int(input("Shift : "))

encrypted = ""

for char in message:
    if char.isalpha():
        if char.isupper():
            encrypted += char((ord(char) -65 + shift ) %26 + 65)

        else:
            encrypted += char((ord(char)-97 + shift) %26 + 97)

# %%
shift = list(range(0,26))

# for i in shift:
#     print(i)

# %%
shift = list(range(1,26))
decrypted = ""
text = "dvvkzecfssprkkve"

for char in text:
    if char.isalpha():
        x = ord(char.isupper() )- ord("A")

# %%
message = "dvvkzecfssprkkve"
shift = list(range(1,26))
encrypted = ""

while True:
    for char in message:
        message = message.lower()
        encrypted += char(char + shift)%26
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       6 for char in message:
#       7     message = message.lower()
# ----> 8     encrypted += char(char + shift)%26
#
# TypeError: can only concatenate str (not "list") to str
